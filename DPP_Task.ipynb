# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("AQI.csv")

df.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
df.shape
# Out:
# (29531, 16)

# %%
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  29531.000000  29531.000000  29531.000000  29531.000000  29531.000000
# mean      64.510857    109.659366     16.642601     27.726576     31.063568
# std       59.807551     72.324020     21.506064     23.050531     29.477748
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       32.150000     79.315000      6.210000     12.980000     14.670000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       72.450000    111.880000     17.570000     34.665000     36.015000
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  29531.000000  29531.000000  29531.000000  29531.000000  29531.000000
# mean      20.813789      2.153872     13.830897     33.994121      2.859874
# std       21.028862      6.724660     17.005647     20.202304     14.252822
# min        0.010000      0.000000      0.010000      0.010000      0.000000
# 25%       12.040000      0.540000      6.090000     20.740000      0.240000
# 50%       15.850000      0.890000      9.160000     30.840000      1.070000
# 75%       21.755000      1.380000     13.810000     42.730000      2.420000
# max      352.890000    175.810000    193.860000    257.730000    455.030000
#
#             Toluene        Xylene           AQI
# count  29531.000000  29531.000000  29531.000000
# mean       7.140485      1.788420    158.781552
# std       17.224737      4.062039    130.272413
# min        0.000000      0.000000     13.000000
# 25%        1.280000      0.980000     88.000000
# 50%        2.970000      0.980000    118.000000
# 75%        6.020000      0.980000    179.000000
# max      454.850000    170.370000   2049.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %% [markdown]
# ## Filling Null Values

# %%
sns.boxplot(x=df['PM2.5'])
plt.show()

# %%
df['PM2.5'] = df['PM2.5'].fillna(df['PM2.5'].median())

# %%
sns.boxplot(x=df['PM10'])
plt.show()

# %%
df['PM10'] = df['PM10'].fillna(df['PM10'].median())

# %%
sns.boxplot(x=df['NO'])
plt.show()

# %%
df['NO'] = df['NO'].fillna(df['NO'].median())

# %%
sns.boxplot(x=df['NO2'])
plt.show()

# %%
df['NO2'] = df['NO2'].fillna(df['NO2'].median())

# %%
sns.boxplot(x=df['NOx'])
plt.show()

# %%
df['NOx'] = df['NOx'].fillna(df['NOx'].median())

# %%
sns.boxplot(x=df['NH3'])
plt.show()

# %%
df['NH3'] = df['NH3'].fillna(df['NH3'].median())

# %%
sns.boxplot(x=df['CO'])
plt.show()

# %%
df['CO'] = df['CO'].fillna(df['CO'].median())

# %%
sns.boxplot(x=df['SO2'])
plt.show()

# %%
df['SO2'] = df['SO2'].fillna(df['SO2'].median())

# %%
sns.boxplot(x=df['O3'])
plt.show()

# %%
df['O3'] = df['O3'].fillna(df['O3'].median())

# %%
sns.boxplot(x=df['Benzene'])
plt.show()

# %%
df['Benzene'] = df['Benzene'].fillna(df['Benzene'].median())

# %%
sns.boxplot(x=df['Toluene'])
plt.show()

# %%
df['Toluene'] = df['Toluene'].fillna(df['Toluene'].median())

# %%
sns.boxplot(x=df['Xylene'])
plt.show()

# %%
df['Xylene'] = df['Xylene'].fillna(df['Xylene'].median())

# %%
sns.boxplot(x=df['AQI'])
plt.show()

# %%
df['AQI'] = df['AQI'].fillna(df['AQI'].median())

# %%
df['AQI_Bucket'] = df['AQI_Bucket'].fillna(df['AQI_Bucket'].mode()[0])

# %%
df.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %% [markdown]
# ## Handling Outliers

# %%
cat_col=df.select_dtypes(include="object").columns
print(cat_col)
# Out:
# Index(['City', 'Date', 'AQI_Bucket'], dtype='object')

# %%
num_cols=df.select_dtypes(include="number").columns
print(num_col)
# Out:
# Index(['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'Xylene', 'AQI'],
#       dtype='object')

# %%
import pandas as pd

# select only numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

def cap_outliers(df, cols):
    df = df.copy()
    
    for col in cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        
        df[col] = df[col].clip(lower, upper)
    
    return df

df = cap_outliers(df, num_cols)

# %%
import pandas as pd

# select only numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

def cap_outliers(df, cols):
    df = df.copy()
    
    for col in cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        
        df[col] = df[col].clip(lower, upper)
    
    return df

df = cap_outliers(df, num_cols)

# %%
import pandas as pd

# select only numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

def cap_outliers(df, cols):
    df = df.copy()
    
    for col in cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        
        df[col] = df[col].clip(lower, upper)
    
    return df

df = cap_outliers(df, num_cols)

# %%
sns.boxplot(x=df['PM2.5'])
plt.show()

# %%
df.describe()
# Out:
#              PM2.5         PM10           NO          NO2          NOx  \
# count  9427.000000  9427.000000  9427.000000  9427.000000  9427.000000
# mean     42.680106    85.164175     8.700770    20.159931    20.292734
# std      17.751975    25.643495     4.647095    10.466694    11.186542
# min       1.720000    30.480000     0.090000     0.010000     0.000000
# 25%      28.430000    65.620000     5.220000    11.500000    11.770000
# 50%      46.140000    95.680000     9.300000    21.690000    23.520000
# 75%      48.570000    95.680000    10.255000    25.100000    24.225000
# max      78.780000   140.770000    17.807500    45.500000    42.907500
#
#                NH3           CO          SO2           O3      Benzene  \
# count  9427.000000  9427.000000  9427.000000  9427.000000  9427.000000
# mean     14.696267     0.826719     7.986671    31.658348     0.885689
# std       5.535495     0.445230     3.527389    14.814485     0.617849
# min       4.525000     0.000000     0.410000     0.010000     0.000000
# 25%      11.380000     0.550000     5.240000    21.475000     0.330000
# 50%      15.850000     0.890000     8.450000    30.840000     1.070000
# 75%      15.950000     1.040000     9.300000    39.725000     1.070000
# max      22.805000     1.775000    15.390000    67.100000     2.180000
#
#            Toluene        Xylene          AQI            z
# count  9427.000000  9.427000e+03  9427.000000  9427.000000
# mean      2.483607  9.800000e-01   103.027686    -0.057208
# std       1.400415  2.354908e-13    34.502868     0.851689
# min       0.000000  9.800000e-01    17.000000    -2.022358
# 25%       1.480000  9.800000e-01    76.000000    -0.740887
# 50%       2.970000  9.800000e-01   105.000000     0.108788
# 75%       2.970000  9.800000e-01   118.000000     0.225373
# max       5.205000  9.800000e-01   181.000000     1.674763

# %%
sns.boxplot(x=df['PM2.5'])
plt.show()

# %% [markdown]
# ##  Data Scaling

# %%
num_cols=df.select_dtypes(include="number").columns
print(num_cols)
# Out:
# Index(['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'Xylene', 'AQI', 'z'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

mm_scaler = MinMaxScaler()
df_mm = df.copy()
df_mm[num_cols] = mm_scaler.fit_transform(df[num_cols])

# %%
df_mm[num_cols].hist(figsize=(12,10), bins=20)
plt.suptitle("MinMax Scaled Distribution")
plt.show()

# %%
num_cols = df.select_dtypes(include='number')

corr = num_cols.corr()

plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()
