# %% [markdown]
# ## Lowercase

# %%
text="I Love $Mechine Learning!!!"
print(text.lower())
# Out:
# i love $mechine learning!!!

# %%
import re

# %%
tex="i love $mechine learning!!!"
tx=re.sub(r"[^a-z/s]"," ",tex)

# %%
tex="i love $mechine learning!!!"
tx=re.sub(r"[^a-z/s]"," ",tex)

# %%
print(tx)
# Out:
# i love  mechine learning

# %% [markdown]
# ## Tokenization

# %%
tokens=text.split()
print(tokens)
# Out:
# ['I', 'Love', '$Mechine', 'Learning!!!']

# %%
tk=tx.split()
print(tk)
# Out:
# ['i', 'love', 'mechine', 'learning']

# %%
## tokenization using nltk library

# %%
# !pip install nltk

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vinod\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\vinod\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
tokens=word_tokenize(text)
print(tokens)
# Out:
# ['I', 'Love', '$', 'Mechine', 'Learning', '!', '!', '!']

# %%
word="I Love $Mechine Learning!@%&*"
tokens=word_tokenize(word)
print(tokens)
# Out:
# ['I', 'Love', '$', 'Mechine', 'Learning', '!', '@', '%', '&', '*']

# %%
word="I Love $Mechine Learning!@%&*"
word.split()
# Out:
# ['I', 'Love', '$Mechine', 'Learning!@%&*']

# %% [markdown]
# ## Sentence Tokenization

# %%
sent="Natural Language Processing  is a branch of artificial intelligence. That enables computers to understand, interpret, and generate human language.!!combining computational linguistics with machine learning.!!!"

# %%
from nltk.tokenize import sent_tokenize
tokens=sent_tokenize(sent)
print(tokens)
# Out:
# ['Natural Language Processing  is a branch of artificial intelligence that enables computers to understand, interpret, and generate human language, combining computational linguistics with machine learning.!!', '!']

# %% [markdown]
# ## Stop Words

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words=set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vinod\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
print(stop_words)
# Out:
# {'after', "shan't", "we'd", "isn't", 'then', 'her', 'wouldn', "couldn't", 'had', 'ain', 'each', 'won', "he'll", 'only', 'some', 'needn', 'as', 'haven', "i'll", 'up', "she'll", "shouldn't", "it'll", "aren't", 'under', 'again', "you've", "mightn't", 'myself', 'couldn', 'their', 'all', "he'd", 'a', 'mustn', 'is', 'where', 'between', 'were', 'he', 'am', 'why', 'can', 'aren', 'no', 'did', 'further', 'herself', "they'll", "weren't", "that'll", "i've", "she's", 'our', 'yourselves', 'or', 'wasn', 'below', 'didn', 'll', "they're", 'd', 'those', 'doing', 'does', 'not', 'shan', 'about', 'are', 'she', 'yourself', 'that', 'there', 't', "i'd", 'any', 'having', 'once', 'through', 'you', 'doesn', "you'll", 'on', 'it', 'me', 'ma', 'and', "doesn't", 'own', "they'd", 'will', 'him', 'so', "you're", 'off', 'over', 'o', 'who', 'was', "he's", "we'll", "i'm", "hasn't", 'than', "we're", "won't", 'isn', 'mightn', "you'd", 'being', "it'd", "didn't", "don't", "wouldn't", 'same', 'theirs', 'both', 'hers', 'very'
# ...

# %%
text="Machine learning is a branch of Artificial Intelligence"
tokens=word_tokenize(text.lower())
print(tokens)
# Out:
# ['machine', 'learning', 'is', 'a', 'branch', 'of', 'artificial', 'intelligence']

# %%
filtered_words=[word for word in tokens if word not in stop_words]
print(filtered_words)
# Out:
# ['machine', 'learning', 'branch', 'artificial', 'intelligence']

# %%
tex= "millions of people worldwide have relied on Machine Learning"
te=tex.lower()

# %%
token=word_tokenize(te)
print(token)
# Out:
# ['millions', 'of', 'people', 'worldwide', 'have', 'relied', 'on', 'machine', 'learning']

# %%
filtered=[word for word in token if word not in stop_words]
print(filtered)
# Out:
# ['millions', 'people', 'worldwide', 'relied', 'machine', 'learning']

# %% [markdown]
# ## Stemming

# %%
from nltk.stem import PorterStemmer

# %%
stemmer=PorterStemmer()
stemmed_words=[stemmer.stem(word) for word in  filtered]
print(stemmed_words)
# Out:
# ['million', 'peopl', 'worldwid', 'reli', 'machin', 'learn']

# %% [markdown]
# ## Lemmatizer

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\vinod\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer=WordNetLemmatizer()
stemmed=[lemmatizer.lemmatize(word) for word in text]
print(stemmed)
# Out:
# ['M', 'a', 'c', 'h', 'i', 'n', 'e', ' ', 'l', 'e', 'a', 'r', 'n', 'i', 'n', 'g', ' ', 'i', 's', ' ', 'a', ' ', 'b', 'r', 'a', 'n', 'c', 'h', ' ', 'o', 'f', ' ', 'A', 'r', 't', 'i', 'f', 'i', 'c', 'i', 'a', 'l', ' ', 'I', 'n', 't', 'e', 'l', 'l', 'i', 'g', 'e', 'n', 'c', 'e']

# %% [markdown]
# ## Lemmatization with POS(More Accurate)

# %%
t="Machine learning is a branch of Artificial Intelligence"

# %%
from nltk.corpus import wordnet 

lemmetized_words=[lemmatizer.lemmatize(word,pos='v') for word in t]
print(lemmetized_words)
# Out:
# ['M', 'a', 'c', 'h', 'i', 'n', 'e', ' ', 'l', 'e', 'a', 'r', 'n', 'i', 'n', 'g', ' ', 'i', 's', ' ', 'a', ' ', 'b', 'r', 'a', 'n', 'c', 'h', ' ', 'o', 'f', ' ', 'A', 'r', 't', 'i', 'f', 'i', 'c', 'i', 'a', 'l', ' ', 'I', 'n', 't', 'e', 'l', 'l', 'i', 'g', 'e', 'n', 'c', 'e']

# %%
s="Deep learning is a subset of machine learning based on artificial neural networks with three or more layers, designed to mimic the human brain's structure to analyze complex patterns in data."

# %%
sen=s.lower()

# %%
w=word_tokenize(sen)

# %%
words=[word for word in w if word not in stop_words]
print(words)
# Out:
# ['deep', 'learning', 'subset', 'machine', 'learning', 'based', 'artificial', 'neural', 'networks', 'three', 'layers', ',', 'designed', 'mimic', 'human', 'brain', "'s", 'structure', 'analyze', 'complex', 'patterns', 'data', '.']

# %%
stemmer=PorterStemmer()
stemmed_words=[stemmer.stem(word) for word in  words]
print(stemmed_words)
# Out:
# ['deep', 'learn', 'subset', 'machin', 'learn', 'base', 'artifici', 'neural', 'network', 'three', 'layer', ',', 'design', 'mimic', 'human', 'brain', "'s", 'structur', 'analyz', 'complex', 'pattern', 'data', '.']
