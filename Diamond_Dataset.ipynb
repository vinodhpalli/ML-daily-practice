# %% [markdown]
# ## DATA UNDERSTANDING & PREPROCESSSING

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("diamonds.csv")
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.shape
# Out:
# (53940, 11)

# %% [markdown]
# ### This dataset contain 53940 rows and 11 columns

# %% [markdown]
# ## Column Structure

# %% [markdown]
# ## 1.carat: It tells how much carts it is DataType:Float
# ## 2.Cut:It tells how it shape is cut Datatype:object
# ## 3.color:it tells what is the colur of dimond Datatype:object
# ## 4.clarity:it tells pure and clear a diamond Datatype:object
# ## 5.depth:it tells height of the dimond Datatype:float
# ## 6.table: Datatype:Float
# ## 7.Price:it tells the price of the Diamond Datatye:int
# ## 8.x:tells length Datatype:Float
# ## 9.y:tells width Datatype:Float
# ## 10.z:tells height Datatype:Float

# %% [markdown]
# ## Step 2 :Intial Data Insepection

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %% [markdown]
# ### Check

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df.nunique()
# Out:
# Unnamed: 0    53940
# carat           273
# cut               5
# color             7
# clarity           8
# depth           184
# table           127
# price         11602
# x               554
# y               552
# z               375
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Step3:DataCleaning

# %% [markdown]
# ### 1.Handling null valus

# %% [markdown]
# ## There is no null values to clean the data

# %% [markdown]
# ## 2.Remove Duplicates

# %% [markdown]
# ## There  is no Duplicate values to remove the duplicates

# %% [markdown]
# ## 3.fix incorrrect datatypes

# %% [markdown]
# ## There is no incorrect datatypes to fix

# %% [markdown]
# ## 4.Satandardiize Column name

# %% [markdown]
# ## No need to change column name

# %% [markdown]
# # Step 4: Explorartary Data Analysis(EDA)

# %% [markdown]
# ### Univriate Analysis

# %%
df.hist(figsize=(12,10),bins=20)

plt.suptitle("Distribution Plot")

plt.show()

# %% [markdown]
# ## Distrubiution plots are used in the univarent anlaysis to understand numericaldata distrubution
# ## Features like price and carat are highly right-skewed

# %% [markdown]
# ## Skewness

# %%
# Select only numeric columns
num_cols = df.select_dtypes(include='number').columns

# KDE plots
for col in num_cols:
    
    plt.figure(figsize=(6,4))
    
    sns.kdeplot(df[col], fill=True)
    
    plt.title(f"KDE Plot of {col}")
    plt.xlabel(col)
    plt.ylabel("Density")
    
    plt.show()

# %% [markdown]
# ### Most of the features are positively skwed
# ### Outliers exist in dimensional attributes

# %% [markdown]
# ## Bivarent analysis

# %%
sns.scatterplot(x='carat', y='price', data=df)
plt.show()

# %% [markdown]
# ## insights
# ### Strong Positive relationship b/w price and carat if carat increses price increses
# ### it shows higher carats contains higher rates

# %% [markdown]
# ## Correlation

# %%
corr = df.corr(numeric_only=True)

print(corr)

# %%
plt.figure(figsize=(10,6))

sns.heatmap(corr,annot=True)

plt.show()

# %% [markdown]
# # insights
# ### Strong Positive Correlation Between carat and price
# ### Dimensions (x, y, z) are Highly Correlated with price

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# ## • Pairplots

# %%
sns.pairplot(df[['carat','depth','table','price']])

plt.show()

# %% [markdown]
# ## insights
# ### Depth and table show weak relationships with price

# %%
sns.scatterplot(x='carat',
                y='price',
                hue='cut',
                data=df)

plt.show()

# %% [markdown]
# #   Step 5: Outlier Detection & Treatment

# %%
num_cols = df.select_dtypes(include='number').columns

plt.figure(figsize=(15,10))

for i, col in enumerate(num_cols):
    plt.subplot(3,3,i+1)

    sns.boxplot(y=df[col])

    plt.title(col)

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# select only numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

def cap_outliers(df, cols):
    df = df.copy()
    
    for col in cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        
        df[col] = df[col].clip(lower, upper)
    
    return df

df = cap_outliers(df, num_cols)

# %%
num_cols = df.select_dtypes(include='number').columns

plt.figure(figsize=(15,10))

for i, col in enumerate(num_cols):
    plt.subplot(3,3,i+1)

    sns.boxplot(y=df[col])

    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# #  Step 6: Feature Encoding

# %% [markdown]
# #### • Convert categorical → numerical:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df["clarity"].nunique()
# Out:
# 8

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder
ct=ColumnTransformer(transformers=[("oe",OrdinalEncoder(),[2,3,4])])

# %%
x_transformed=ct.fit_transform(x)

# %%
x_transofrmed=pd.DataFrame(x_transformed,columns=x.columns)
x_transofrmed

# %% [markdown]
# #  Step 7: Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
ct=ColumnTransformer(transformers=[("sc",StandardScaler(),[0,1,5,6,8,9,10])])

# %%
x_transformed=ct.fit_transform(x)

# %% [markdown]
# # Step 8: Train-Test Split

# %%
## target variable
y=df["price"]

# %%
## input varibles 13 columns
x=df.drop(["price"],axis=1)

# %%
# train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
