# %%
# !pip install movie_reviews
# Out:
# Requirement already satisfied: movie_reviews in c:\users\admin\anaconda3\lib\site-packages (0.0.2)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas>=1.4.4 in c:\users\admin\anaconda3\lib\site-packages (from movie_reviews) (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.4.4->movie_reviews) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.4.4->movie_reviews) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.4.4->movie_reviews) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.4.4->movie_reviews) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.4->movie_reviews) (1.17.0)

# %%
# !pip install -U textblob
# Out:
# Requirement already satisfied: textblob in c:\users\admin\anaconda3\lib\site-packages (0.19.0)
# Collecting textblob
#   Downloading textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: nltk>=3.9 in c:\users\admin\anaconda3\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\admin\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in c:\users\admin\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\admin\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.20.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    ---------------------------------------- 625.0/625.0 kB 964.3 kB/s  0:00:00
# Installing collected packages: textblob
#   Attempting uninstall: textblob
#     Found existing installation: textblob 0.19.0
#     Uninstalling textblob-0.19.0:
#       Successfully uninstalled textblob-0.19.0
# Successfully installed textblob-0.20.0
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from movie_reviews import reviews
import random
from textblob import TextBlob # provides text mining, text analysis and text processing modules
from IPython.display import clear_output # Clear the output in Jupyter Notebook

# %%
def get_sentiment(rev):
    """Function which return the sentiment of the passed review as positive, negative or Neutral"""
    analysis = TextBlob(rev)
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity <0:
        return 'negative'
    else:
        return 'neutral'

# %%
def get_reviews(num_of_review,movie_name):
    """Processing of the review and returns a list, that consist of multiple dictionary with their respective text & sentiment"""
    # Selection of Random reviews
    selected_reviews = [random.choice(reviews[movie_name]) for _ in range(num_of_review)]
    print("First two reviews of the movie: \n")
    print(selected_reviews[0],"\n")
    print(selected_reviews[1],"\n")
    final_processed_review = []
    for inner_list in selected_reviews:
        # Empty dictionary to store required params of a review
        parsed_review = {}
        # saving text of the reviews
        parsed_review['text'] = inner_list[0]
        # saving sentiment of the reviews by passing the review to get_sentiment function
        parsed_review['sentiment'] = get_sentiment(inner_list[0])
        final_processed_review.append(parsed_review)
    return final_processed_review

# %%
def analyze():
    print(list(reviews.keys()))
    movie_name = input("Select a movie you want to analyze: ")
    if movie_name in list(reviews.keys()):
        num_of_review = int(input("Enter the number of reviews you want to analyze: "))
        clear_output()  # Clear the output in Jupyter Notebook
        review = get_reviews(num_of_review,movie_name)
        # Picking positive reviews
        positive_reviews=[]
        for item in review:
            if item["sentiment"] == "positive":
                positive_reviews.append(item)
        # Percentage of positive reviews
        print("Positive reviews percentage: {} %".format(100*len(positive_reviews)/(num_of_review)))
        # Picking negative reviews
        negative_reviews = [rev1 for rev1 in review if rev1["sentiment"] == "negative"]
        # Percentage of negative reviews
        print("Negative reviews percentage: {} %".format(100*len(negative_reviews)/(num_of_review)))
        # Percentage of neutral reviews
        print("Neutral reviews percentage: {} %".format(100*((num_of_review) - len(negative_reviews) - len(positive_reviews))/(num_of_review)))
    else:
        return "Movie not found in the list"

# %%
analyze()
# Out:
# First two reviews of the movie:
#
# ['The message of this film seems to be that the way to successfully negotiate the world is to be as ignorant as possible - thought and intelligence are the enemies to happiness. As a teacher I find this reactionary twaddle, designed to encourage people to be humble and know their place, acutely antithetical to everything I believe in.']
#
# ["Forrest Gump is the best movie ever made. When I first saw it I only sat through the first minute of it and turned it off. After growing with my age and watching a lot of other movies, Forrest Gump was the one that I couldn't take my eyes off of. Forrest Gump is the first movie since Titanic that has made me cry because of Tom Hanks and Gary Sinises outstanding performances. Almost never in my life have I been captivated by a movie and how it played out. Forrest Gump is neither too long or too short, for me it never dragged along and made me bored. Out of the six Oscars that Forrest Gump won, this movie rightfully deserved all of it. Pretty much everything made sense to me which made this movie really great for me. All in all I give Forrest Gump a 10 and think that this is a movie that should be watched for the rest of time."]
#
# Positive reviews percentage: 100.0 %
# Negative reviews percentage: 0.0 %
# Neutral reviews percentage: 0.0 %
