# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## correlation _Based Feature Selection

# %%
df = pd.read_csv("winequality-red.csv")

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
## target
y=df["quality"]

# %%
#predictors
x=df.drop('quality',axis=1)

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
 sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Varience Threshold

# %%
data=pd.DataFrame({
    'A':[1,1,1,1,1],
    'B':[1,2,3,4,5],
    'c':[0,0,0,1,0]
})

# %%
from sklearn.feature_selection import VarianceThreshold
vt=VarianceThreshold(threshold=0) 
vt.fit
# Out:
# <bound method VarianceThreshold.fit of VarianceThreshold(threshold=0)>

# %%
X_new = vt.fit_transform(data)

selected_features = data.columns[vt.get_support()]
print(selected_features)
# Out:
# Index(['B', 'c'], dtype='object')

# %%
#varience Threshold
from sklearn.feature_selection import VarianceThreshold 
var_thres=VarianceThreshold(threshold=0.2)
var_thres.fit(x)
# Out:
# VarianceThreshold(threshold=0.2)

# %%
best_features=x.columns[var_thres.get_support()]
print(best_features)
# Out:
# Index(['fixed acidity', 'residual sugar', 'free sulfur dioxide',
#        'total sulfur dioxide', 'alcohol'],
#       dtype='object')

# %% [markdown]
# ## Mutual Information(MI)

# %%
from sklearn.feature_selection import mutual_info_regression
mi_scores=mutual_info_regression(x,y)
mi_df=pd.DataFrame({
    'Feature':x.columns,
    'MI_Score':mi_scores
}).sort_values(by='MI_Score',ascending=False)
print(mi_df)
# Out:
#                  Feature  MI_Score
# 10               alcohol  0.193219
# 7                density  0.091241
# 1       volatile acidity  0.090311
# 6   total sulfur dioxide  0.088193
# 0          fixed acidity  0.069817
# 9              sulphates  0.068653
# 2            citric acid  0.034824
# 4              chlorides  0.027960
# 3         residual sugar  0.023955
# 8                     pH  0.011104
# 5    free sulfur dioxide  0.006620

# %% [markdown]
# ## MI For Classification Problems
